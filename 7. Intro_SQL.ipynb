# %% [markdown]
# # 7. SQL
#
#
#
#
# * Programming language: MySQL
#
#
#
# ## Subjects covered
# * Data definition language (DDL)
# * Data manipulation language (DML)
# * Data control language (DCL)
# * Relational schemas: primary and foregin key
# * Data types: string, boolean, integer, time
# * Create database statement
# * Create table statement
# * Select statment
# * Contraints: unique, default, not null
# * Select from
# * And, or, between
# * In and not in, like and not like
# * Select distinct
# * Group by and order by
# * Where and having
# * Insert statement
# * Update statement: commit and rollback
# * Delete statement: drop vs truncate, delete
# * Aggregate functions: count(), sum(), min(), max(), avg(), etc
# * Inner, left, right, and cross join
# * Union and union all
# * Subqueries with in nested inside where
# * Subqueries with exist-not exist nested inside where
# * Subqueries nested in slect and from
# * SQl views
# * Stored procedures and user-defined functions
# * Session and global variables
# * Triggers
# * Case statements
# * Combining SQL and Tableau
# * Coding techniques and best practices
#
#
#
# ## Projects performed
#
# * proj-7.1 mysql_constraints_may2022
# * proj-7.2 select_statements
# * proj-7.3 update_statements
# * proj-7.4 insert_statements
# * proj-7.5 aggregate_functions
# * proj-7.6 sytax_sql_queries_may2022
# * proj-7.7 sql_subqueries
# * proj-7.8 sql_joins_statements
# * proj-7.9 combing_sql_tableau
# * proj-7.10 stored_routines
# * proj-7.11 variables_triggers_indexes
# * proj-7.12 final_query_questions
#
#
#
# ## Course and matrials
# SQL - MySQL for Data Analytics and Business Intelligence on Udemy
